# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils
# Out:
# /Users/volterr/anaconda/envs/dlnd/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:35, 879KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

t = 1e-5
c = Counter(int_words)
total = len(int_words)
freq = {w: c[w]/total for w in c}
p = {w: 1 - np.sqrt(t/freq[w]) for w in c}

train_words = [w for w in int_words if random.random() > p[w]]# The final subsampled word list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, (None), name='inputs')
    labels = tf.placeholder(tf.int32, (None, None), name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6713 0.2084 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5997 0.2240 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5327 0.2263 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5823 0.2186 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4808 0.2045 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5636 0.2028 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5376 0.2031 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5341 0.2118 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4893 0.2043 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4041 0.2026 sec/batch
# Nearest to they: guards, announced, maddox, brazzaville, acceded, welling, anniversary, eastman,
# Nearest to however: neared, disenchantment, obliged, dollywood, homecoming, thoroughly, night, webcam,
# Nearest to nine: dumped, disturbing, quds, packers, sacked, novum, raza, calais,
# Nearest to known: ova, physique, sports, geoffrey, one, absurd, superfluid, bobby,
# Nearest to only: priming, herri, sarmatian, banded, wont, spend, settlement, significant,
# Nearest to this: runway, thinly, honeybees, codification, elphame, yezhov, zacharias, wreaked,
# Nearest to new: eurocheque, beginnings, contingencies, accuracy, selected, sarcophagi, commits, silverman,
# Nearest to eight: pant, pied, storks, abhidharma, burrell, tsuba, dent, ebrahim,
# Nearest to creation: hymnal, ailment, into, aristocratic, rime, moeller, mortem, puzzle,
# Nearest to san: festa, peso, marlborough, obligate, ethica, visitor, phoca, deems,
# Nearest to governor: rhenish, source, roads, limbic, occured, calculation, attu, yohannes,
# Nearest to troops: indoors, maximillian, eth, powermac, beset, federalism, iles, patristic,
# Nearest to dr: wigner, forecasted, cavan, nee, iamblichus, democratisation, precognition, crystallographic,
# Nearest to operations: intolerable, trump, dvds, altdorfer, dune, macintosh, eminent, indeterminate,
# Nearest to defense: gimbutas, polydentate, practice, dona, gakuin, pruning, insignificant, suggests,
# Nearest to lived: scotia, plutonium, leila, mobygames, feeder, knocking, monogram, biographie,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4921 0.2074 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3696 0.2152 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3355 0.2028 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2537 0.2064 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2209 0.2056 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1740 0.2053 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0885 0.2033 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0713 0.2224 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0095 0.2079 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9686 0.2087 sec/batch
# Nearest to they: announced, guards, without, brazzaville, anniversary, prototype, contrast, ask,
# Nearest to however: neared, disenchantment, night, second, evelyn, served, thoroughly, except,
# Nearest to nine: dumped, disturbing, quds, mi, transported, dropped, expansion, sacked,
# Nearest to known: sports, operate, unfortunately, one, heavily, ova, physique, linguistic,
# Nearest to only: significant, settlement, spend, grandson, tickets, priming, flavia, taverns,
# Nearest to this: runway, codification, honeybees, zacharias, yezhov, wolf, surprising, feared,
# Nearest to new: selected, accuracy, appointed, vernacular, astrophysicists, traditionally, beginnings, economist,
# Nearest to eight: pant, doctrine, evacuated, green, burrell, dent, pied, national,
# Nearest to creation: into, puzzle, aristocratic, hymnal, similar, there, popularly, instruments,
# Nearest to san: festa, peso, marlborough, visitor, issue, obligate, deems, four,
# Nearest to governor: source, rhenish, calculation, roads, occured, legacy, burns, identically,
# Nearest to troops: indoors, eth, movement, maximillian, federalism, beset, centralized, powermac,
# Nearest to dr: wigner, need, forecasted, criminal, relatively, participation, precision, iamblichus,
# Nearest to operations: intolerable, dvds, eminent, accordingly, macintosh, simpson, may, allocating,
# Nearest to defense: practice, polydentate, suggests, dona, gimbutas, ethiopia, mouth, entertainers,
# Nearest to lived: plutonium, scotia, leila, pc, mobygames, dispose, lenticular, destroyer,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9183 0.2222 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9198 0.2097 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8907 0.2085 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8510 0.2089 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7998 0.2052 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8303 0.2093 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8034 0.2070 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7702 0.2061 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7748 0.2090 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7934 0.2235 sec/batch
# Nearest to they: guards, announced, acceded, contrast, prototype, brazzaville, rural, ask,
# Nearest to however: neared, thoroughly, obliged, disenchantment, night, conversion, dollywood, accord,
# Nearest to nine: dumped, disturbing, quds, sacked, mi, calais, poorest, novum,
# Nearest to known: ova, bobby, offers, linguistic, geoffrey, heavily, absurd, physique,
# Nearest to only: significant, settlement, spend, tickets, priming, sarmatian, rejection, arabia,
# Nearest to this: runway, thinly, codification, wolf, yezhov, feared, zacharias, honeybees,
# Nearest to new: beginnings, selected, appointed, accuracy, economist, dismissed, collins, coasts,
# Nearest to eight: six, burrell, pied, evacuated, green, xii, heathrow, dent,
# Nearest to creation: into, formalism, hymnal, puzzle, aristocratic, ailment, migrations, popularly,
# Nearest to san: festa, peso, visitor, hydraulics, obligate, trips, pim, marlborough,
# Nearest to governor: source, roads, calculation, legacy, occured, announcement, rhenish, identically,
# Nearest to troops: indoors, beset, federalism, eth, enlightenment, centralized, movement, iles,
# Nearest to dr: wigner, forecasted, nee, iamblichus, precision, need, participation, incorporating,
# Nearest to operations: intolerable, dvds, eminent, accordingly, dune, macintosh, labeling, simpson,
# Nearest to defense: practice, ethiopia, dona, tender, insignificant, polydentate, motivations, gimbutas,
# Nearest to lived: scotia, plutonium, leila, feeder, dispose, destroyer, mobygames, treasurer,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7931 0.2109 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7531 0.2050 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.6820 0.2035 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7057 0.2038 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7665 0.2060 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6877 0.2065 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7130 0.2064 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7293 0.2069 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6907 0.2064 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6715 0.2046 sec/batch
# Nearest to they: guards, acceded, solace, without, contrast, announced, brazzaville, voluntarily,
# Nearest to however: neared, obliged, disenchantment, thoroughly, night, toxicity, dollywood, accord,
# Nearest to nine: dumped, quds, disturbing, sacked, calais, musician, prime, one,
# Nearest to known: ova, bobby, offers, geoffrey, absurd, heavily, sports, physique,
# Nearest to only: significant, priming, verdicts, rejection, circuitry, sarmatian, flavia, valerie,
# Nearest to this: runway, thinly, codification, yezhov, honeybees, wolf, intersects, zacharias,
# Nearest to new: beginnings, vernacular, selected, appointed, coasts, commits, collins, economist,
# Nearest to eight: six, burrell, pied, xii, four, russian, rus, louis,
# Nearest to creation: formalism, into, ailment, hymnal, judah, aristocratic, puzzle, rime,
# Nearest to san: festa, obligate, hydraulics, four, stateless, trips, pim, dor,
# Nearest to governor: rhenish, occured, roads, source, identically, legacy, announcement, trial,
# Nearest to troops: indoors, beset, movement, struggle, iles, enlightenment, powermac, suspend,
# Nearest to dr: wigner, iamblichus, nee, forecasted, democratisation, sketching, guernica, vibrate,
# Nearest to operations: intolerable, dvds, dune, sheikh, allocating, labeling, macintosh, eminent,
# Nearest to defense: practice, ethiopia, gimbutas, polydentate, insignificant, dona, motivations, heteroatom,
# Nearest to lived: scotia, plutonium, feeder, leila, treasurer, monogram, destroyer, dispose,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6711 0.2043 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6591 0.2127 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6263 0.2291 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6495 0.2104 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6218 0.2074 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6323 0.2094 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5704 0.1715 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5464 0.2168 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5360 0.2082 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5012 0.2100 sec/batch
# Nearest to they: guards, without, solace, contrast, acceded, prototype, would, rural,
# Nearest to however: neared, thoroughly, disenchantment, obliged, dollywood, night, toxicity, accord,
# Nearest to nine: dumped, musician, one, quds, kim, george, songwriter, sacked,
# Nearest to known: ova, geoffrey, bobby, offers, absurd, sanitarium, marianne, strange,
# Nearest to only: verdicts, priming, significant, flavia, nativist, circuitry, rejection, wont,
# Nearest to this: runway, thinly, yezhov, codification, viaje, honeybees, breadth, intersects,
# Nearest to new: beginnings, selected, vernacular, commits, eurocheque, extramarital, collins, sarcophagi,
# Nearest to eight: six, pied, burrell, four, xii, louis, russian, bassist,
# Nearest to creation: formalism, hymnal, ailment, into, judah, aristocratic, mortem, popularly,
# Nearest to san: festa, four, obligate, trips, dor, assassinate, gropius, michaels,
# Nearest to governor: rhenish, occured, bonne, roads, government, identically, announcement, trial,
# Nearest to troops: indoors, beset, struggle, iles, movement, powermac, ussr, enlightenment,
# Nearest to dr: wigner, iamblichus, democratisation, nee, forecasted, guernica, sketching, paymaster,
# Nearest to operations: intolerable, dvds, macintosh, allocating, dune, indeterminate, labeling, sheikh,
# Nearest to defense: practice, gimbutas, polydentate, tender, insignificant, heteroatom, bilateral, motivations,
# Nearest to lived: scotia, plutonium, feeder, leila, treasurer, mobygames, monogram, destroyer,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5053 0.2143 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4923 0.2186 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4709 0.2226 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5400 0.2255 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4634 0.2293 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4807 0.2312 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4588 0.2318 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3659 17.1549 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4314 0.2187 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4437 0.2156 sec/batch
# Nearest to they: guards, solace, without, acceded, contrast, voluntarily, ask, would,
# Nearest to however: thoroughly, disenchantment, neared, obliged, toxicity, accord, dollywood, terms,
# Nearest to nine: dumped, disturbing, mi, unveiling, grievance, quds, musician, novum,
# Nearest to known: ova, offers, sanitarium, strange, geoffrey, energize, marianne, absurd,
# Nearest to only: priming, verdicts, significant, flavia, nativist, circuitry, rejection, sarmatian,
# Nearest to this: runway, codification, thinly, yezhov, surprising, be, breadth, particle,
# Nearest to new: beginnings, selected, vernacular, eurocheque, extramarital, itn, commits, collins,
# Nearest to eight: six, burrell, pied, four, louis, xii, rus, dent,
# Nearest to creation: formalism, hymnal, ailment, into, popularly, judah, rime, mortem,
# Nearest to san: festa, four, los, athlete, visitor, michaels, hunsr, colonist,
# Nearest to governor: rhenish, government, occured, announcement, bonne, trial, brugge, corrupt,
# Nearest to troops: indoors, beset, iles, powermac, struggle, archbishopric, suspend, ussr,
# Nearest to dr: democratisation, wigner, iamblichus, forecasted, nee, guernica, paymaster, madman,
# Nearest to operations: macintosh, dvds, allocating, intolerable, horizontal, dune, commutative, indeterminate,
# Nearest to defense: bilateral, gimbutas, practice, clip, polydentate, tender, dona, motivations,
# Nearest to lived: scotia, feeder, plutonium, leila, treasurer, mobygames, monogram, destroyer,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4162 0.2096 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4290 0.2081 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4214 0.2227 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4117 72.1812 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3947 3.6083 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4347 0.2071 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3597 0.2091 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3905 0.2373 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3918 0.2395 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3887 0.2365 sec/batch
# Nearest to they: guards, solace, would, acceded, without, contrast, voluntarily, ask,
# Nearest to however: thoroughly, neared, disenchantment, obliged, terms, radiotherapy, dollywood, toxicity,
# Nearest to nine: dumped, linda, musician, disturbing, sacked, quds, jaime, unveiling,
# Nearest to known: ova, strange, sanitarium, offers, energize, truthful, geoffrey, marianne,
# Nearest to only: priming, verdicts, discussed, rejection, significant, circuitry, bet, wont,
# Nearest to this: runway, thinly, breadth, codification, surprising, yezhov, solicit, intersects,
# Nearest to new: beginnings, selected, vernacular, eurocheque, extramarital, collins, telegraphic, itn,
# Nearest to eight: six, burrell, four, pied, louis, mathematician, five, xii,
# Nearest to creation: formalism, hymnal, ailment, into, popularly, judah, mortem, rime,
# Nearest to san: festa, four, los, trips, michaels, athlete, visitor, motte,
# Nearest to governor: rhenish, government, announcement, occured, trial, bonne, minister, elamo,
# Nearest to troops: indoors, beset, iles, powermac, archbishopric, suspend, ussr, struggle,
# Nearest to dr: democratisation, wigner, iamblichus, guernica, madman, forecasted, autograph, nee,
# Nearest to operations: dvds, macintosh, allocating, horizontal, commutative, intolerable, dune, indeterminate,
# Nearest to defense: gimbutas, bilateral, tender, practice, clip, insignificant, polydentate, qimei,
# Nearest to lived: scotia, feeder, plutonium, monogram, treasurer, destroyer, brother, prsc,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3719 0.2163 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3671 0.2047 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3464 0.2082 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3906 0.2250 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3959 0.2169 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3719 0.2130 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4218 0.2087 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3889 0.2019 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3364 0.2039 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3426 0.2003 sec/batch
# Nearest to they: guards, would, solace, contrast, acceded, without, voluntarily, commonsense,
# Nearest to however: thoroughly, neared, obliged, disenchantment, terms, accord, dollywood, radiotherapy,
# Nearest to nine: dumped, grievance, unveiling, quds, linda, economist, dropped, mi,
# Nearest to known: ova, strange, energize, sanitarium, offers, absurd, linguistic, judicious,
# Nearest to only: priming, verdicts, rejection, nativist, assuming, in, expletive, significant,
# Nearest to this: thinly, runway, codification, breadth, surprising, solicit, honeybees, saussure,
# Nearest to new: beginnings, eurocheque, vernacular, selected, telegraphic, extramarital, collins, itn,
# Nearest to eight: six, burrell, four, pied, five, one, louis, liechtenstein,
# Nearest to creation: formalism, hymnal, into, ailment, popularly, judah, mcluhan, rime,
# Nearest to san: festa, los, four, visitor, trips, motte, dor, michaels,
# Nearest to governor: rhenish, announcement, unicameral, government, trial, evan, justices, corrupt,
# Nearest to troops: indoors, beset, suspend, ussr, powermac, iles, struggle, vietnam,
# Nearest to dr: democratisation, wigner, guernica, forecasted, madman, iamblichus, autograph, nee,
# Nearest to operations: dvds, allocating, macintosh, horizontal, commutative, id, dune, thujone,
# Nearest to defense: practice, bilateral, gimbutas, tender, motivations, clip, qimei, imposition,
# Nearest to lived: scotia, feeder, plutonium, monogram, brother, treasurer, illegitimate, ezekiel,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3421 0.2052 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2956 0.2035 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3960 0.2025 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3793 0.2022 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4055 0.2041 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3139 0.2165 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3084 0.2349 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3386 0.2294 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2517 0.2220 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2912 0.2136 sec/batch
# Nearest to they: guards, would, solace, contrast, without, commonsense, anyway, acceded,
# Nearest to however: thoroughly, obliged, neared, disenchantment, terms, dollywood, accord, except,
# Nearest to nine: one, four, dumped, zero, linda, grievance, jaime, six,
# Nearest to known: ova, sanitarium, strange, absurd, linguistic, offers, energize, downforce,
# Nearest to only: priming, verdicts, assuming, expletive, nativist, rejection, hanoverians, wont,
# Nearest to this: runway, codification, thinly, wreaked, surprising, breadth, honeybees, solicit,
# Nearest to new: beginnings, eurocheque, selected, vernacular, extramarital, telegraphic, itn, maureen,
# Nearest to eight: six, burrell, four, pied, one, five, louis, mathematician,
# Nearest to creation: hymnal, formalism, into, ailment, popularly, judah, mortem, mcluhan,
# Nearest to san: festa, los, trips, explodes, motte, dor, hunsr, michaels,
# Nearest to governor: rhenish, announcement, trial, evan, occured, justices, unicameral, brugge,
# Nearest to troops: indoors, suspend, ussr, beset, powermac, iles, vietnam, archbishopric,
# Nearest to dr: democratisation, forecasted, guernica, madman, wigner, iamblichus, burgess, autograph,
# Nearest to operations: dvds, allocating, commutative, macintosh, horizontal, sphincter, id, dune,
# Nearest to defense: practice, tender, bilateral, imposition, motivations, gimbutas, qimei, accommodated,
# Nearest to lived: scotia, feeder, plutonium, hilversum, monogram, ezekiel, treasurer, leila,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2800 0.2140 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2892 0.2108 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3327 0.1108 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2424 0.2106 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2447 0.2103 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2289 0.2114 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1995 0.2100 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1952 0.2106 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2389 0.2100 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1893 0.2109 sec/batch
# Nearest to they: guards, would, solace, contrast, without, bicycle, anyway, rural,
# Nearest to however: thoroughly, neared, obliged, disenchantment, toxicity, homecoming, dollywood, terms,
# Nearest to nine: dumped, one, prime, linda, zero, unveiling, four, jaime,
# Nearest to known: ova, sanitarium, strange, compostela, linguistic, energize, genres, offers,
# Nearest to only: priming, expletive, verdicts, assuming, nativist, expected, hanoverians, bet,
# Nearest to this: runway, thinly, codification, wreaked, surprising, breadth, amesbury, solicit,
# Nearest to new: beginnings, selected, eurocheque, vernacular, telegraphic, extramarital, maureen, commits,
# Nearest to eight: six, four, burrell, pied, five, one, two, seven,
# Nearest to creation: hymnal, formalism, into, ailment, mortem, petomane, warplanes, mcluhan,
# Nearest to san: festa, los, trips, explodes, hunsr, motte, defensive, dor,
# Nearest to governor: announcement, rhenish, evan, unicameral, trial, justices, brugge, appoints,
# Nearest to troops: indoors, suspend, powermac, iles, beset, archbishopric, ussr, airborne,
# Nearest to dr: democratisation, guernica, wigner, forecasted, iamblichus, madman, autograph, paymaster,
# Nearest to operations: dvds, commutative, horizontal, allocating, id, macintosh, line, sphincter,
# Nearest to defense: tender, practice, imposition, bilateral, accommodated, qimei, motivations, clip,
# Nearest to lived: scotia, feeder, plutonium, hilversum, ezekiel, skie, brother, monogram,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2345 0.2127 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2121 0.2091 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2045 0.2103 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1305 0.2115 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1884 0.2098 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1671 0.2125 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1729 0.2106 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1649 0.2101 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1971 0.2110 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1596 0.2103 sec/batch
# Nearest to they: guards, would, contrast, solace, anyway, without, bicycle, smash,
# Nearest to however: thoroughly, neared, disenchantment, toxicity, obliged, dollywood, homecoming, shield,
# Nearest to nine: zero, one, three, four, total, six, unveiling, dumped,
# Nearest to known: ova, sanitarium, strange, krafft, energize, linguistic, vulgar, offers,
# Nearest to only: priming, assuming, expected, bet, expletive, verdicts, circuitry, transitive,
# Nearest to this: surprising, wreaked, runway, breadth, be, honeybees, thinly, codification,
# Nearest to new: beginnings, selected, eurocheque, vernacular, telegraphic, extramarital, capoeiristas, repository,
# Nearest to eight: six, four, burrell, five, two, one, pied, seven,
# Nearest to creation: hymnal, formalism, into, mcluhan, petomane, warplanes, rime, human,
# Nearest to san: los, festa, motte, trips, hunsr, defensive, visitor, marino,
# Nearest to governor: announcement, rhenish, unicameral, evan, trial, justices, appoints, brugge,
# Nearest to troops: indoors, beset, powermac, suspend, evacuated, retreating, ussr, archbishopric,
# Nearest to dr: democratisation, guernica, madman, autograph, forecasted, iamblichus, wigner, paymaster,
# Nearest to operations: commutative, allocating, dvds, line, horizontal, macintosh, id, bunt,
# Nearest to defense: tender, practice, accommodated, lindbergh, bilateral, qimei, imposition, strategic,
# Nearest to lived: scotia, feeder, plutonium, hilversum, ezekiel, leila, skie, brother,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1628 0.2132 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2064 0.2115 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1495 0.2142 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1418 0.2122 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.2062 0.2106 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1856 0.2125 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1965 0.2130 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1898 0.2118 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1309 0.2126 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1546 0.2119 sec/batch
# Nearest to they: guards, would, contrast, solace, anyway, ask, voluntarily, smash,
# Nearest to however: thoroughly, neared, obliged, disenchantment, toxicity, dollywood, shield, homecoming,
# Nearest to nine: one, three, four, zero, total, six, economist, unveiling,
# Nearest to known: ova, strange, sanitarium, gaia, vulgar, genres, krafft, absurd,
# Nearest to only: priming, expected, bet, assuming, expletive, ten, verdicts, transitive,
# Nearest to this: breadth, surprising, wreaked, thinly, codification, honeybees, accelerator, runway,
# Nearest to new: beginnings, selected, eurocheque, vernacular, telegraphic, extramarital, reprint, repository,
# Nearest to eight: six, four, burrell, one, five, two, seven, pied,
# Nearest to creation: hymnal, formalism, into, mcluhan, warplanes, petomane, rime, mortem,
# Nearest to san: los, festa, motte, hunsr, trips, dor, michaels, visitor,
# Nearest to governor: unicameral, evan, announcement, appoints, rhenish, justices, chief, government,
# Nearest to troops: retreating, evacuated, suspend, indoors, archbishopric, beset, cordiale, powermac,
# Nearest to dr: democratisation, guernica, forecasted, madman, autograph, wigner, iamblichus, paymaster,
# Nearest to operations: commutative, allocating, id, dvds, line, bunt, horizontal, gauge,
# Nearest to defense: practice, tender, accommodated, bilateral, qimei, lindbergh, imposition, strategic,
# Nearest to lived: scotia, plutonium, feeder, hilversum, skie, plebeian, biographie, brother,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2061 0.2148 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1948 0.2144 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1664 0.2106 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1979 0.2124 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1306 0.2142 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1063 0.2115 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1891 0.2125 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.0920 0.2135 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2125 0.2130 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2278 0.2129 sec/batch
# Nearest to they: guards, would, contrast, solace, anyway, voluntarily, passages, tamed,
# Nearest to however: neared, thoroughly, obliged, disenchantment, dollywood, accord, thessaly, shield,
# Nearest to nine: one, three, four, zero, six, two, economist, total,
# Nearest to known: ova, sanitarium, strange, gaia, compostela, hejira, absurd, vulgar,
# Nearest to only: priming, expected, ten, bet, verdicts, monopolize, flavia, becoming,
# Nearest to this: breadth, wreaked, surprising, codification, runway, thinly, honeybees, theogony,
# Nearest to new: selected, beginnings, eurocheque, vernacular, reprint, telegraphic, extramarital, repay,
# Nearest to eight: six, four, one, five, burrell, two, seven, pied,
# Nearest to creation: hymnal, into, formalism, warplanes, mcluhan, petomane, jamiroquai, mortem,
# Nearest to san: los, festa, hunsr, motte, michaels, dor, uta, marino,
# Nearest to governor: evan, announcement, unicameral, rhenish, brugge, justices, appoints, executive,
# Nearest to troops: evacuated, indoors, retreating, cordiale, powermac, archbishopric, battle, suspend,
# Nearest to dr: guernica, democratisation, madman, forecasted, autograph, wigner, burgess, paymaster,
# Nearest to operations: commutative, allocating, bunt, id, line, dvds, gx, indonesia,
# Nearest to defense: practice, motivations, tender, accommodated, qimei, bilateral, imposition, lindbergh,
# Nearest to lived: scotia, skie, hilversum, ezekiel, plutonium, plebeian, biographie, leila,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2348 0.2159 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1218 0.2130 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1525 0.2115 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1894 0.2119 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0504 0.2135 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1453 0.2138 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1494 0.2122 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1394 0.2132 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1975 0.0598 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0981 0.2130 sec/batch
# Nearest to they: guards, would, contrast, solace, anyway, parameters, enough, dive,
# Nearest to however: neared, thoroughly, obliged, disenchantment, dollywood, shield, thessaly, radiotherapy,
# Nearest to nine: one, three, zero, six, four, two, total, hashish,
# Nearest to known: ova, sanitarium, gaia, compostela, strange, vulgar, genres, absurd,
# Nearest to only: priming, ten, bet, expected, becoming, expletive, verdicts, spinoff,
# Nearest to this: wreaked, surprising, be, runway, breadth, thinly, honeybees, in,
# Nearest to new: beginnings, selected, eurocheque, vernacular, telegraphic, reprint, repository, contingencies,
# Nearest to eight: six, four, two, one, five, burrell, seven, pied,
# Nearest to creation: hymnal, formalism, into, warplanes, jamiroquai, mcluhan, petomane, sci,
# Nearest to san: los, festa, hunsr, stateless, trips, marino, uta, dor,
# Nearest to governor: evan, unicameral, announcement, rhenish, appoints, brugge, attu, justices,
# Nearest to troops: evacuated, indoors, retreating, cordiale, archbishopric, powermac, ussr, battle,
# Nearest to dr: guernica, democratisation, madman, forecasted, autograph, wigner, burgess, paymaster,
# Nearest to operations: commutative, allocating, id, bunt, line, jtc, claymore, gx,
# Nearest to defense: accommodated, practice, tender, motivations, qimei, lindbergh, bilateral, nazarian,
# Nearest to lived: scotia, plutonium, hilversum, ezekiel, skie, biographie, plebeian, leila,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0559 0.2168 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0800 0.2144 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1039 0.2045 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0686 0.2136 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0704 0.2145 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0347 0.2123 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1138 0.2835 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0940 0.2920 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1065 0.2911 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.9862 0.2997 sec/batch
# Nearest to they: guards, would, contrast, anyway, solace, algebra, voluntarily, enough,
# Nearest to however: thoroughly, neared, obliged, dollywood, event, terms, exacerbated, toxicity,
# Nearest to nine: one, three, zero, six, four, two, total, hashish,
# Nearest to known: ova, sanitarium, compostela, gaia, offers, strange, vulgar, genres,
# Nearest to only: expected, priming, ten, becoming, verdicts, bet, hanoverians, flavia,
# Nearest to this: breadth, surprising, be, wreaked, codification, runway, honeybees, elegantly,
# Nearest to new: beginnings, eurocheque, selected, repository, telegraphic, vernacular, reprint, pippen,
# Nearest to eight: six, four, two, five, one, burrell, seven, pied,
# Nearest to creation: hymnal, formalism, into, mcluhan, jamiroquai, warplanes, petomane, merging,
# Nearest to san: los, hunsr, festa, trips, stateless, motte, marino, tucson,
# Nearest to governor: announcement, evan, unicameral, justices, attu, appoints, commons, rhenish,
# Nearest to troops: evacuated, cordiale, indoors, retreating, powermac, airborne, suspend, diatribe,
# Nearest to dr: guernica, democratisation, madman, forecasted, autograph, wigner, burgess, promoting,
# Nearest to operations: commutative, allocating, id, bunt, line, claymore, y, pseudocode,
# Nearest to defense: accommodated, tender, practice, motivations, bilateral, nazarian, qimei, lindbergh,
# Nearest to lived: scotia, plutonium, hilversum, leila, plebeian, biographie, skie, ezekiel,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0566 0.3090 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0409 0.3162 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0347 0.3150 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0385 0.3153 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0661 0.3105 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0542 0.3046 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0643 0.2949 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1244 0.2965 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0638 0.2969 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0771 0.2960 sec/batch
# Nearest to they: guards, would, contrast, anyway, algebra, solace, swears, dive,
# Nearest to however: neared, thoroughly, terms, radiotherapy, obliged, shield, event, disenchantment,
# Nearest to nine: one, three, zero, six, two, four, total, murrow,
# Nearest to known: ova, sanitarium, strange, compostela, perishable, gaia, vulgar, krafft,
# Nearest to only: priming, expected, ten, assuming, verdicts, transitive, becoming, bet,
# Nearest to this: in, be, breadth, surprising, wreaked, designating, honeybees, is,
# Nearest to new: beginnings, reprint, vernacular, selected, eurocheque, repository, telegraphic, azteca,
# Nearest to eight: six, four, two, one, five, burrell, seven, pied,
# Nearest to creation: hymnal, formalism, into, mcluhan, warplanes, jamiroquai, petomane, daimon,
# Nearest to san: los, hunsr, festa, stateless, trips, bedtime, tucson, marino,
# Nearest to governor: evan, announcement, unicameral, attu, justices, appoints, rhenish, brugge,
# Nearest to troops: evacuated, indoors, cordiale, retreating, powermac, diatribe, federalism, airborne,
# Nearest to dr: guernica, forecasted, madman, autograph, wigner, burgess, democratisation, anechoic,
# Nearest to operations: commutative, allocating, bunt, id, line, pseudocode, indeterminate, constructors,
# Nearest to defense: accommodated, practice, tender, nazarian, qimei, bilateral, motivations, strategic,
# Nearest to lived: scotia, hilversum, plutonium, plebeian, biographie, skie, feeder, renown,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0519 0.3007 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0782 0.3079 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0616 0.3017 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0707 0.3025 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0598 0.3045 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0513 0.3031 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0586 0.2327 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0909 0.4590 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0850 0.2630 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0675 0.2734 sec/batch
# Nearest to they: guards, would, contrast, algebra, anyway, unsealed, dive, solace,
# Nearest to however: neared, obliged, terms, shield, thoroughly, disenchantment, radiotherapy, event,
# Nearest to nine: one, three, zero, two, four, six, total, hashish,
# Nearest to known: ova, sanitarium, gaia, strange, compostela, vulgar, krafft, hejira,
# Nearest to only: expected, priming, ten, becoming, verdicts, bet, dwelt, proposing,
# Nearest to this: in, surprising, breadth, wreaked, dago, be, theogony, numeration,
# Nearest to new: beginnings, reprint, repository, telegraphic, eurocheque, selected, vernacular, pippen,
# Nearest to eight: six, four, two, one, five, burrell, seven, pied,
# Nearest to creation: hymnal, into, formalism, jamiroquai, mcluhan, warplanes, daimon, merging,
# Nearest to san: los, hunsr, festa, dor, stateless, bedtime, tucson, uta,
# Nearest to governor: evan, announcement, unicameral, appoints, justices, cantrell, brugge, attu,
# Nearest to troops: evacuated, cordiale, retreating, beset, indoors, powermac, federalism, diatribe,
# Nearest to dr: guernica, madman, forecasted, autograph, wigner, democratisation, burgess, pkp,
# Nearest to operations: commutative, allocating, bunt, id, snedden, svenska, claymore, pseudocode,
# Nearest to defense: accommodated, practice, nazarian, tender, qimei, motivations, imposition, lindbergh,
# Nearest to lived: scotia, hilversum, plutonium, plebeian, skie, ezekiel, biographie, renown,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0692 0.2605 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0137 0.2210 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0444 0.2301 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0680 0.2350 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0726 0.2433 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1337 0.2309 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1186 0.2174 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0350 0.2854 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0347 0.2212 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0495 0.2066 sec/batch
# Nearest to they: guards, would, contrast, algebra, facilitator, unsealed, dive, anyway,
# Nearest to however: neared, terms, shield, radiotherapy, obliged, toxicity, thoroughly, event,
# Nearest to nine: one, three, zero, four, two, six, total, hashish,
# Nearest to known: ova, sanitarium, strange, gaia, compostela, absurd, vulgar, finnegans,
# Nearest to only: priming, expected, ten, proposing, becoming, assuming, verdicts, expletive,
# Nearest to this: in, breadth, be, wreaked, surprising, is, dago, azeotrope,
# Nearest to new: repository, beginnings, selected, reprint, telegraphic, eurocheque, vernacular, pippen,
# Nearest to eight: six, four, one, two, five, burrell, seven, pied,
# Nearest to creation: hymnal, into, formalism, jamiroquai, mcluhan, warplanes, sci, merging,
# Nearest to san: los, tucson, festa, hunsr, uta, bedtime, dor, clambake,
# Nearest to governor: evan, appoints, announcement, attu, brugge, chief, cantrell, bjelke,
# Nearest to troops: evacuated, cordiale, retreating, indoors, federalism, brigadier, reinforcements, powermac,
# Nearest to dr: guernica, madman, forecasted, burgess, autograph, wigner, democratisation, pkp,
# Nearest to operations: commutative, allocating, id, svenska, bunt, jtc, pseudocode, claymore,
# Nearest to defense: accommodated, practice, qimei, motivations, tender, nazarian, imposition, lindbergh,
# Nearest to lived: scotia, hilversum, plutonium, skie, plebeian, ezekiel, biographie, aedui,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9922 0.2073 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0335 0.2058 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0357 0.2056 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0518 0.2039 sec/batch
# Epoch 5/10 Iteration: 18500 Avg. Training loss: 4.0821 0.0087 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0640 0.2051 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0244 0.2055 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9860 0.2054 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0112 0.2045 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9966 0.2048 sec/batch
# Nearest to they: guards, would, algebra, shortness, anyway, unsealed, contrast, dive,
# Nearest to however: neared, thoroughly, shield, terms, dollywood, event, radiotherapy, billionaires,
# Nearest to nine: one, three, four, two, six, zero, five, total,
# Nearest to known: ova, sanitarium, compostela, gaia, strange, vulgar, finnegans, period,
# Nearest to only: expected, ten, priming, proposing, verdicts, becoming, memeplex, bet,
# Nearest to this: in, wreaked, surprising, be, breadth, the, by, as,
# Nearest to new: beginnings, selected, reprint, repository, vernacular, extramarital, telegraphic, azteca,
# Nearest to eight: six, four, two, one, five, seven, burrell, zero,
# Nearest to creation: hymnal, into, formalism, jamiroquai, mcluhan, warplanes, collectors, koblenz,
# Nearest to san: los, tucson, hunsr, uta, festa, trips, bedtime, stateless,
# Nearest to governor: evan, announcement, bjelke, unicameral, attu, appoints, brugge, chancery,
# Nearest to troops: evacuated, cordiale, retreating, indoors, brigadier, federalism, reinforcements, powermac,
# Nearest to dr: guernica, madman, forecasted, democratisation, burgess, autograph, wigner, pkp,
# Nearest to operations: commutative, allocating, svenska, id, snedden, claymore, bunt, jtc,
# Nearest to defense: accommodated, motivations, practice, tender, qimei, nazarian, lindbergh, imposition,
# Nearest to lived: hilversum, scotia, plutonium, skie, plebeian, remainder, aedui, callistus,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9843 0.2074 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9811 0.2051 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9977 0.2041 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0351 0.2028 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0185 0.2033 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9877 0.2056 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9183 0.2064 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9603 0.2044 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9216 0.2035 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9946 0.2034 sec/batch
# Nearest to they: would, guards, anyway, algebra, swears, facilitator, solace, dive,
# Nearest to however: event, terms, thoroughly, neared, shield, dollywood, hydrolyzed, billionaires,
# Nearest to nine: one, three, two, four, zero, six, total, five,
# Nearest to known: ova, sanitarium, compostela, gaia, vulgar, strange, bv, acropolis,
# Nearest to only: ten, expected, priming, proposing, assuming, dwelt, differing, becoming,
# Nearest to this: in, be, surprising, the, breadth, by, is, wreaked,
# Nearest to new: beginnings, reprint, repository, selected, naia, vernacular, replace, extramarital,
# Nearest to eight: six, four, two, one, five, seven, zero, burrell,
# Nearest to creation: hymnal, into, formalism, jamiroquai, mcluhan, warplanes, collectors, gouvernement,
# Nearest to san: los, tucson, hunsr, stateless, riverside, uta, trips, clambake,
# Nearest to governor: evan, announcement, bjelke, attu, appoints, unicameral, brugge, rhenish,
# Nearest to troops: evacuated, cordiale, retreating, vukovar, indoors, brigadier, federalism, reinforcements,
# Nearest to dr: guernica, forecasted, madman, autograph, burgess, pkp, wigner, geophysical,
# Nearest to operations: commutative, svenska, allocating, bunt, snedden, id, jtc, claymore,
# Nearest to defense: accommodated, motivations, practice, tender, nazarian, qimei, lindbergh, strategic,
# Nearest to lived: hilversum, plutonium, scotia, plebeian, aedui, skie, callistus, cycladic,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9986 0.2074 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0081 0.2045 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9862 0.2039 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0297 0.2043 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0242 0.2057 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9582 0.2051 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9795 0.2042 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0264 0.2050 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9865 0.2055 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0458 0.2051 sec/batch
# Nearest to they: would, guards, anyway, are, algebra, facilitator, swears, contrast,
# Nearest to however: terms, event, neared, thoroughly, radiotherapy, dollywood, billionaires, shield,
# Nearest to nine: one, three, six, four, two, zero, five, eight,
# Nearest to known: ova, sanitarium, strange, compostela, gaia, vulgar, orchestras, often,
# Nearest to only: expected, priming, ten, rejected, proposing, supercomputers, assuming, becoming,
# Nearest to this: in, be, surprising, breadth, the, by, azeotrope, as,
# Nearest to new: beginnings, reprint, repository, selected, vernacular, tib, telegraphic, collins,
# Nearest to eight: six, four, one, two, five, seven, zero, burrell,
# Nearest to creation: hymnal, into, formalism, mcluhan, jamiroquai, warplanes, collectors, highpoint,
# Nearest to san: los, tucson, hunsr, stateless, clambake, riverside, uta, dor,
# Nearest to governor: evan, bjelke, appoints, attu, announcement, brugge, chancery, cantrell,
# Nearest to troops: evacuated, cordiale, retreating, federalism, brigadier, reinforcements, indoors, vukovar,
# Nearest to dr: guernica, autograph, madman, burgess, forecasted, wigner, democratisation, pkp,
# Nearest to operations: commutative, svenska, bunt, allocating, snedden, claymore, treat, representable,
# Nearest to defense: accommodated, motivations, practice, nazarian, qimei, tender, fes, strategic,
# Nearest to lived: hilversum, plutonium, plebeian, scotia, biographie, callistus, aedui, cycladic,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0198 0.2073 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9872 0.2052 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9725 0.2052 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9906 0.2060 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9903 0.2060 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9905 0.2041 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 4.0053 0.2047 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9230 0.2051 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9703 0.2028 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0340 0.2068 sec/batch
# Nearest to they: would, guards, anyway, algebra, are, swears, facilitator, had,
# Nearest to however: terms, event, neared, obliged, radiotherapy, accord, continuing, fully,
# Nearest to nine: one, three, two, four, six, zero, five, eight,
# Nearest to known: ova, sanitarium, strange, gaia, vulgar, compostela, selim, acropolis,
# Nearest to only: proposing, expected, ten, priming, kabbala, becoming, verdicts, rejected,
# Nearest to this: in, be, by, the, surprising, as, breadth, azeotrope,
# Nearest to new: reprint, beginnings, repository, selected, telegraphic, vernacular, pippen, tib,
# Nearest to eight: six, four, one, two, five, seven, zero, nine,
# Nearest to creation: hymnal, into, formalism, jamiroquai, mcluhan, warplanes, debased, validate,
# Nearest to san: los, tucson, clambake, hunsr, stateless, uta, dor, festa,
# Nearest to governor: evan, appoints, bjelke, chancery, brugge, justices, chief, attu,
# Nearest to troops: evacuated, federalism, cordiale, retreating, indoors, reinforcements, brigadier, vukovar,
# Nearest to dr: guernica, autograph, madman, burgess, forecasted, democratisation, wigner, geophysical,
# Nearest to operations: commutative, svenska, allocating, bunt, claymore, treat, snedden, jtc,
# Nearest to defense: accommodated, nazarian, motivations, practice, qimei, tender, strategic, fes,
# Nearest to lived: hilversum, plutonium, aedui, scotia, plebeian, cycladic, biographie, renown,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9804 0.2080 sec/batch
# ...
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.9163 0.2042 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8676 0.2046 sec/batch
# Nearest to they: their, are, to, that, regurgitated, would, anyway, did,
# Nearest to however: although, not, of, than, most, are, very, terms,
# Nearest to nine: one, four, three, six, two, zero, five, eight,
# Nearest to known: in, as, are, also, and, been, by, often,
# Nearest to only: be, is, in, it, proposing, all, however, differing,
# Nearest to this: in, is, the, as, by, and, that, a,
# Nearest to new: york, collins, reprint, beginnings, emmerson, philadelphia, azteca, replace,
# Nearest to eight: six, one, four, two, seven, five, nine, zero,
# Nearest to creation: into, hymnal, interlinked, validate, maximized, created, koblenz, concepts,
# Nearest to san: los, obispo, california, francisco, tucson, jose, hunsr, clambake,
# Nearest to governor: bjelke, evan, appoint, confidence, attu, morison, governors, angiotensin,
# Nearest to troops: evacuated, reinforcements, army, surrendered, vukovar, crossed, retreating, federalism,
# Nearest to dr: intoxicated, autograph, bjp, incorporating, ana, districts, madman, guernica,
# Nearest to operations: representable, treat, claymore, commutative, whitlock, burks, allocating, psychoactive,
# Nearest to defense: accommodated, elliptic, motivations, strategic, rotors, wiring, defenses, baseless,
# Nearest to lived: fergus, spoke, remainder, years, hilversum, spent, censors, cycladic,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8223 0.2067 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8308 0.2050 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8996 0.2047 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8604 0.2053 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8453 0.2049 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8875 0.2061 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8388 0.2065 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8534 0.2058 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8784 0.2067 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8997 0.2057 sec/batch
# Nearest to they: are, their, did, to, anyway, them, regurgitated, would,
# Nearest to however: although, not, of, than, very, fully, as, a,
# Nearest to nine: one, four, three, five, six, zero, two, eight,
# Nearest to known: in, as, are, other, and, often, on, were,
# Nearest to only: be, is, proposing, in, however, expected, it, becoming,
# Nearest to this: in, the, by, is, and, as, that, for,
# Nearest to new: york, collins, emmerson, reprint, beginnings, annotations, replace, tib,
# Nearest to eight: six, one, four, two, five, seven, nine, zero,
# Nearest to creation: into, hymnal, interlinked, maximized, koblenz, validate, debased, anthem,
# Nearest to san: los, obispo, tucson, francisco, california, hunsr, clambake, dor,
# Nearest to governor: bjelke, confidence, evan, appoint, governors, appoints, attu, chief,
# Nearest to troops: evacuated, reinforcements, army, surrendered, diatribe, retreating, comintern, envelopment,
# Nearest to dr: intoxicated, districts, bjp, madman, incorporating, autograph, guernica, ana,
# Nearest to operations: representable, treat, commutative, claymore, whitlock, burks, psychoactive, distantly,
# Nearest to defense: accommodated, motivations, elliptic, strategic, qimei, baseless, rotors, nazarian,
# Nearest to lived: spoke, fergus, years, spent, hilversum, remainder, censors, cycladic,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8518 0.2089 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8514 0.2061 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8109 0.2060 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8190 0.2056 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8974 0.2084 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8271 0.2077 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9563 0.2062 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9515 0.2051 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8735 0.2054 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8176 0.2061 sec/batch
# Nearest to they: are, their, them, did, anyway, regurgitated, would, algebra,
# Nearest to however: although, of, most, not, very, fully, breakthrough, than,
# Nearest to nine: one, four, six, three, five, two, zero, eight,
# Nearest to known: are, as, include, in, been, most, often, also,
# Nearest to only: be, is, proposing, in, however, it, rejected, could,
# Nearest to this: in, is, the, and, by, be, as, that,
# Nearest to new: york, collins, emmerson, reprint, philadelphia, beginnings, replace, increased,
# Nearest to eight: six, one, four, seven, two, five, nine, zero,
# Nearest to creation: into, hymnal, koblenz, interlinked, maximized, anthem, yassin, concepts,
# Nearest to san: los, obispo, tucson, california, francisco, clambake, marino, hunsr,
# Nearest to governor: bjelke, evan, confidence, appoint, governors, attu, appoints, morison,
# Nearest to troops: evacuated, reinforcements, army, surrendered, shatila, vukovar, indoors, diatribe,
# Nearest to dr: intoxicated, districts, bjp, autograph, madman, series, ana, incorporating,
# Nearest to operations: treat, representable, commutative, claymore, whitlock, operation, burks, psychoactive,
# Nearest to defense: motivations, accommodated, elliptic, strategic, baseless, qimei, inquisitors, gakuin,
# Nearest to lived: fergus, spoke, remainder, hilversum, spent, years, educated, immigrated,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8645 0.2068 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8034 0.2054 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8426 0.2069 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8500 0.2071 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8315 0.2051 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8787 0.2053 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8682 0.1742 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8389 0.2075 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8181 0.2081 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8613 0.2067 sec/batch
# Nearest to they: their, are, did, would, algebra, to, regurgitated, them,
# Nearest to however: although, not, breakthrough, a, only, very, having, since,
# Nearest to nine: one, four, three, six, five, eight, two, zero,
# Nearest to known: are, as, in, also, been, most, and, several,
# Nearest to only: is, be, in, proposing, however, could, that, it,
# Nearest to this: in, the, is, as, and, by, that, to,
# Nearest to new: york, collins, emmerson, reprint, beginnings, replace, philadelphia, tib,
# Nearest to eight: one, six, four, seven, two, five, nine, zero,
# Nearest to creation: into, hymnal, koblenz, interlinked, maximized, anthem, yassin, validate,
# Nearest to san: los, obispo, tucson, hunsr, francisco, marino, california, clambake,
# Nearest to governor: bjelke, evan, confidence, appoint, morison, appoints, governors, attu,
# Nearest to troops: evacuated, reinforcements, army, surrendered, vukovar, shatila, crossed, indoors,
# Nearest to dr: intoxicated, districts, ana, bjp, autograph, incorporating, permeation, prayed,
# Nearest to operations: representable, treat, commutative, claymore, burks, whitlock, psychoactive, svenska,
# Nearest to defense: motivations, accommodated, elliptic, baseless, lo, strategic, rotors, defenses,
# Nearest to lived: remainder, spoke, fergus, censors, educated, spent, hilversum, inclusively,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8106 0.2100 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8111 0.2057 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7959 0.2063 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8309 0.2058 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8316 0.2062 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8639 0.2053 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8602 0.2059 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7413 0.2056 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7960 0.2066 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7687 0.2052 sec/batch
# Nearest to they: their, are, did, would, regurgitated, anyway, algebra, had,
# Nearest to however: although, not, than, breakthrough, a, very, only, most,
# Nearest to nine: one, six, four, three, five, two, eight, zero,
# Nearest to known: in, are, as, also, and, other, been, most,
# Nearest to only: be, is, in, however, proposing, all, that, it,
# Nearest to this: in, is, the, as, a, with, and, for,
# Nearest to new: york, collins, emmerson, reprint, replace, philadelphia, tib, beginnings,
# Nearest to eight: six, one, four, two, seven, five, nine, zero,
# Nearest to creation: into, hymnal, maximized, koblenz, interlinked, validate, environmentalist, anthem,
# Nearest to san: los, obispo, california, tucson, francisco, hunsr, marino, jose,
# Nearest to governor: bjelke, evan, confidence, appoint, morison, attu, governors, appoints,
# Nearest to troops: reinforcements, evacuated, army, vukovar, shatila, surrendered, envelopment, indoors,
# Nearest to dr: districts, intoxicated, ana, bjp, series, autograph, prayed, permeation,
# Nearest to operations: representable, treat, commutative, burks, psychoactive, claymore, whitlock, exarchate,
# Nearest to defense: accommodated, elliptic, motivations, strategic, rotors, lo, logistics, infiltration,
# Nearest to lived: remainder, spoke, fergus, years, hilversum, immigrated, cycladic, aeta,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7796 0.2088 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8427 0.2059 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8595 0.2053 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7942 0.2064 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8620 0.2076 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8777 0.2061 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8118 0.2067 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8344 0.2052 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8526 0.2067 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8247 0.2064 sec/batch
# Nearest to they: their, are, did, regurgitated, to, them, anyway, would,
# Nearest to however: although, only, not, a, than, of, are, most,
# Nearest to nine: one, four, six, three, five, two, eight, zero,
# Nearest to known: are, in, as, also, often, were, been, other,
# Nearest to only: be, is, however, proposing, in, and, it, that,
# Nearest to this: in, is, the, as, and, be, a, to,
# Nearest to new: york, collins, emmerson, reprint, philadelphia, beginnings, azteca, replace,
# Nearest to eight: one, six, four, seven, two, five, nine, three,
# Nearest to creation: into, hymnal, maximized, validate, koblenz, interlinked, environmentalist, concepts,
# Nearest to san: los, obispo, california, tucson, francisco, hunsr, marino, clambake,
# Nearest to governor: bjelke, evan, appoint, confidence, morison, governors, attu, appoints,
# Nearest to troops: evacuated, army, reinforcements, vukovar, envelopment, surrendered, vietnam, shatila,
# Nearest to dr: intoxicated, districts, series, bjp, incorporating, autograph, ana, permeation,
# Nearest to operations: representable, treat, commutative, operation, whitlock, claymore, homomorphisms, psychoactive,
# Nearest to defense: accommodated, elliptic, motivations, strategic, rotors, lo, baseless, wiring,
# Nearest to lived: years, spoke, remainder, fergus, hilversum, dominatrixes, immigrated, spent,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8649 0.2086 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8396 0.2055 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8397 0.2079 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8296 0.2072 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8570 0.2063 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8446 0.2065 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8444 0.2064 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8251 0.2063 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8106 0.2076 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8163 0.2053 sec/batch
# Nearest to they: their, are, them, to, had, regurgitated, enough, did,
# Nearest to however: although, not, only, of, as, a, that, most,
# Nearest to nine: one, four, three, six, five, two, zero, eight,
# Nearest to known: are, as, other, in, and, which, also, most,
# Nearest to only: is, be, however, it, proposing, that, in, and,
# Nearest to this: in, the, is, by, and, a, to, as,
# Nearest to new: york, collins, emmerson, reprint, replace, azteca, philadelphia, annotations,
# Nearest to eight: six, one, four, two, five, seven, zero, three,
# Nearest to creation: into, hymnal, maximized, koblenz, of, interlinked, validate, created,
# Nearest to san: los, obispo, tucson, francisco, california, marino, hunsr, clambake,
# Nearest to governor: evan, bjelke, appoint, confidence, morison, headed, governors, appoints,
# Nearest to troops: evacuated, reinforcements, army, envelopment, vukovar, surrendered, invaded, psara,
# Nearest to dr: districts, bjp, intoxicated, incorporating, autograph, ana, guernica, prayed,
# Nearest to operations: representable, treat, commutative, operation, whitlock, claymore, psychoactive, homomorphisms,
# Nearest to defense: accommodated, elliptic, motivations, strategic, rotors, baseless, infiltration, defenses,
# Nearest to lived: spoke, years, remainder, aeta, fergus, cycladic, censors, spent,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8932 0.2109 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8248 0.2088 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9624 0.2076 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8932 0.2056 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9106 0.2067 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8235 0.2076 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7799 0.2045 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8644 0.2049 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7799 0.2064 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8813 0.2061 sec/batch
# Nearest to they: their, are, them, enough, regurgitated, did, to, had,
# Nearest to however: although, not, that, of, only, most, a, as,
# Nearest to nine: one, three, six, four, five, two, zero, eight,
# Nearest to known: are, as, also, other, in, most, were, and,
# Nearest to only: is, it, be, however, proposing, that, in, could,
# Nearest to this: in, is, the, as, and, that, a, with,
# Nearest to new: york, collins, emmerson, reprint, azteca, replace, philadelphia, beginnings,
# Nearest to eight: one, six, four, seven, two, nine, five, zero,
# Nearest to creation: into, interlinked, koblenz, maximized, anthem, created, hymnal, validate,
# Nearest to san: los, obispo, california, tucson, francisco, hunsr, clambake, marino,
# Nearest to governor: evan, bjelke, confidence, appoint, headed, governors, sonny, morison,
# Nearest to troops: army, evacuated, reinforcements, vukovar, surrendered, vietnam, shatila, envelopment,
# Nearest to dr: districts, bjp, intoxicated, incorporating, series, prayed, autograph, ana,
# Nearest to operations: representable, treat, commutative, operation, psychoactive, whitlock, claymore, exarchate,
# Nearest to defense: elliptic, accommodated, motivations, strategic, defenses, baseless, infiltration, lo,
# Nearest to lived: spoke, remainder, fergus, years, spent, censors, aeta, hilversum,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8035 0.2086 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8386 0.2064 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
